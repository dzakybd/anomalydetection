# %% [markdown]
# ## Load library

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from scipy import stats
from scipy.signal import find_peaks
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn import preprocessing 
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
import seaborn as sns
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score
from pickle import dump
from numpy.random import seed
import tensorflow
from sklearn.model_selection import ShuffleSplit
# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import roc_curve
from numpy import quantile

rseed = 1
seed(rseed)
tensorflow.random.set_seed(rseed)
sns.set(style="whitegrid")

# %% [markdown]
# # Data preprocessing

# %%
data = pd.read_csv('creditcard.csv') # Load data
data = data.drop(columns=['Time']) # drop unused variable 'Time'
print(data.isnull().values.any()) # Check if the data has missing value

data
# Out:
# False
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 30 columns]

# %%
print(data["Class"].value_counts()) #Class distribution
data["Class"].value_counts().plot(kind='bar')
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# ### Normalization

# %%
scaled = preprocessing.MinMaxScaler().fit_transform(data.values)
data_scale = pd.DataFrame(scaled, columns=data.columns, index=data.index)
data_scale
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0       0.935192  0.766490  0.881365  0.313023  0.763439  0.267669  0.266815
# 1       0.978542  0.770067  0.840298  0.271796  0.766120  0.262192  0.264875
# 2       0.935217  0.753118  0.868141  0.268766  0.762329  0.281122  0.270177
# 3       0.941878  0.765304  0.868484  0.213661  0.765647  0.275559  0.266803
# 4       0.938617  0.776520  0.864251  0.269796  0.762975  0.263984  0.268968
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.756448  0.873531  0.666991  0.160317  0.729603  0.236810  0.235393
# 284803  0.945845  0.766677  0.872678  0.219189  0.771561  0.273661  0.265504
# 284804  0.990905  0.764080  0.781102  0.227202  0.783425  0.293496  0.263547
# 284805  0.954209  0.772856  0.849587  0.282508  0.763172  0.269291  0.261175
# 284806  0.949232  0.765256  0.849601  0.229488  0.765632  0.256488  0.274963
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 0       0.786444  0.475312  0.510600  ...  0.561184  0.522992  0.663793
# 1       0.786298  0.453981  0.505267  ...  0.557840  0.480237  0.666938
# 2       0.788042  0.410603  0.513018  ...  0.565477  0.546030  0.678939
# 3       0.789434  0.414999  0.507585  ...  0.559734  0.510277  0.662607
# 4       0.782484  0.490950  0.524303  ...  0.561327  0.547271  0.663392
# ...          ...       ...       ...  ...       ...       ...       ...
# 284802  0.863749  0.528729  0.598850  ...  0.564920  0.515249  0.680500
# 284803  0.788548  0.482925  0.488530  ...  0.564933  0.553153  0.665619
# 284804  0.792985  0.477677  0.498692  ...  0.565220  0.537005  0.664877
# 284805  0.792671  0.476287  0.500464  ...  0.565755  0.547353  0.663008
# 284806  0.780938  0.479528  0.489782  ...  0.565688  0.540031  0.671029
#
#              V24       V25       V26       V27       V28    Amount  Class
# 0       0.391253  0.585122  0.394557  0.418976  0.312697  0.005824    0.0
# 1       0.336440  0.587290  0.446013  0.416345  0.313423  0.000105    0.0
# 2       0.289354  0.559515  0.402727  0.415489  0.311911  0.014739    0.0
# 3       0.223826  0.614245  0.389197  0.417669  0.314371  0.004807    0.0
# 4       0.401270  0.566343  0.507497  0.420561  0.317490  0.002724    0.0
# ...          ...       ...       ...       ...       ...       ...    ...
# 284802  0.313600  0.658558  0.466291  0.433929  0.329840  0.000030    0.0
# 284803  0.245298  0.543855  0.360884  0.417775  0.312038  0.000965    0.0
# 284804  0.468492  0.592824  0.411177  0.416593  0.312585  0.002642    0.0
# 284805  0.398836  0.545958  0.514746  0.418520  0.315245  0.000389    0.0
# 284806  0.383420  0.551319  0.291786  0.416466  0.313401  0.008446    0.0
#
# [284807 rows x 30 columns]

# %% [markdown]
# ### Data splitting

# %%
y = data_scale["Class"].values
X_normal, X_fraud = data_scale[y == 0], data_scale[y == 1]
Y_normal, Y_fraud = np.zeros(X_normal.shape[0]), np.ones(X_fraud.shape[0])

outlier_fraction = len(Y_fraud)/float(len(Y_normal))
print("Outlier fraction:", outlier_fraction)
print("Fraud Cases : {}".format(len(Y_fraud)))
print("Valid Cases : {}".format(len(Y_normal)))

# X_train_all, X_test_all, Y_train_all, Y_test_all = train_test_split(data_scale, y, test_size=0.2)

# Splitting Train & Test of Normal data
X_train_normal, X_test_normal, Y_train_normal, Y_test_normal = train_test_split(X_normal, Y_normal, test_size=0.2)
# Splitting Train & Test of Fraud data
X_train_fraud, X_test_fraud, Y_train_fraud, Y_test_fraud = train_test_split(X_fraud, Y_fraud, test_size=0.2)

# Combine Train Normal & Fraud data
X_train_all = np.append(X_train_normal, X_train_fraud, axis = 0)
Y_train_all = np.append(Y_train_normal, Y_train_fraud).astype(int)

# Combine Test Normal & Fraud data
X_test_all = np.append(X_test_normal, X_test_fraud, axis = 0)
Y_test_all = np.append(Y_test_normal, Y_test_fraud).astype(int)

# Combine Test Normal with All Fraud data
# Used for testing on Semi-supervised
X_test_afwn = np.append(X_test_normal, X_fraud, axis = 0)
Y_test_afwn = np.append(Y_test_normal, Y_fraud)
# Out:
# Outlier fraction: 0.0017304750013189597
# Fraud Cases : 492
# Valid Cases : 284315

# %% [markdown]
# # Model building & Evaluation

# %%
# GridSearch setting
cv = ShuffleSplit(test_size=0.2, n_splits=1, random_state=rseed)

def evaluation_matrix(Y_test_all, y_pred):
    print(classification_report(Y_test_all,y_pred))
    matrix = confusion_matrix(Y_test_all, y_pred)
    labels = ['Normal', 'Fraud']
    g=sns.heatmap(matrix,annot=True, cbar=False, fmt='g', xticklabels=labels, yticklabels=labels)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.title('Confusion matrix of IsolationForest')
    plt.show()
    
# def evaluation_roc(Y_test_all, y_probs):
#     fpr, tpr, _ = roc_curve(Y_test_all, y_probs)
#     auc = roc_auc_score(Y_test_all, y_probs)
#     print("AUC Score:", auc)
#     plt.plot(fpr, tpr, linestyle='--')
#     # axis labels
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     # show the legend
#     plt.legend()
#     # show the plot
#     plt.show()

# %% [markdown]
# ## Isolation forest (unsupervised)

# %%
param_grid = {'n_estimators': [100, 150, 200],
            'max_samples': ['auto', 100],
            'contamination': [outlier_fraction, 'auto']}
f1_ms = make_scorer(f1_score, average='binary', pos_label=-1)

clf_if = IsolationForest(random_state=rseed)
clf_if = GridSearchCV(clf_if, param_grid, cv=cv, scoring=f1_ms, verbose=100)

# Provide class label with sklearn format
Y_train_all_2 = Y_train_all.copy()
Y_train_all_2[Y_train_all_2 == 1] = -1
Y_train_all_2[Y_train_all_2 == 0] = 1

clf_if.fit(X_train_all, Y_train_all_2)
# Out:
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] contamination=0.0017304750013189597, max_samples=auto, n_estimators=100
# [CV]  contamination=0.0017304750013189597, max_samples=auto, n_estimators=100, score=0.277, total=  14.2s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   14.2s remaining:    0.0s
# [CV] contamination=0.0017304750013189597, max_samples=auto, n_estimators=150
# [CV]  contamination=0.0017304750013189597, max_samples=auto, n_estimators=150, score=0.297, total=  20.7s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   34.9s remaining:    0.0s
# [CV] contamination=0.0017304750013189597, max_samples=auto, n_estimators=200
# [CV]  contamination=0.0017304750013189597, max_samples=auto, n_estimators=200, score=0.284, total=  27.5s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  1.0min remaining:    0.0s
# [CV] contamination=0.0017304750013189597, max_samples=100, n_estimators=100
# [CV]  contamination=0.0017304750013189597, max_samples=100, n_estimators=100, score=0.259, total=  13.5s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.3min remaining:    0.0s
# [CV] contamination=0.0017304750013189597, max_samples=100, n_estimators=150
# [CV]  contamination=0.0017304750013189597, max_samples=100, n_estimators=150, score=0.257, total=  20.3s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.6min remaining:    0.0s
# [CV] contamination=0.0017304750013189597, max_samples=100, n_estimators=200
# [CV]  contamination=0.0017304750013189597, max_samples=100, n_estimators=200, score=0.260, total=  26.9s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  2.1min remaining:    0.0s
# [CV] contamination=auto, max_samples=auto, n_estimators=100 ..........
# [CV]  contamination=auto, max_samples=auto, n_estimators=100, score=0.074, total=   7.8s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  2.2min remaining:    0.0s
# [CV] contamination=auto, max_samples=auto, n_estimators=150 ..........
# [CV]  contamination=auto, max_samples=auto, n_estimators=150, score=0.073, total=  11.5s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  2.4min remaining:    0.0s
# [CV] contamination=auto, max_samples=auto, n_estimators=200 ..........
# [CV]  contamination=auto, max_samples=auto, n_estimators=200, score=0.073, total=  15.4s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  2.6min remaining:    0.0s
# [CV] contamination=auto, max_samples=100, n_estimators=100 ...........
# [CV]  contamination=auto, max_samples=100, n_estimators=100, score=0.045, total=   7.6s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  2.8min remaining:    0.0s
# [CV] contamination=auto, max_samples=100, n_estimators=150 ...........
# [CV]  contamination=auto, max_samples=100, n_estimators=150, score=0.043, total=  11.4s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  2.9min remaining:    0.0s
# [CV] contamination=auto, max_samples=100, n_estimators=200 ...........
# [CV]  contamination=auto, max_samples=100, n_estimators=200, score=0.044, total=  15.2s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  3.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  3.2min finished
# GridSearchCV(cv=ShuffleSplit(n_splits=1, random_state=1, test_size=0.2, train_size=None),
#              estimator=IsolationForest(random_state=1),
#              param_grid={'contamination': [0.0017304750013189597, 'auto'],
#                          'max_samples': ['auto', 100],
#                          'n_estimators': [100, 150, 200]},
#              scoring=make_scorer(f1_score, average=binary, pos_label=-1),
#              verbose=100)

# %%
# Gridsearch Parameter Tuning result
print(clf_if.best_params_)
print(clf_if.best_score_)
dump(clf_if.best_estimator_, open('isolation_forest.pkl', 'wb'))
# Out:
# {'contamination': 0.0017304750013189597, 'max_samples': 'auto', 'n_estimators': 150}
# 0.2967741935483871

# %%
y_pred = clf_if.best_estimator_.predict(X_test_all)
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1

evaluation_matrix(Y_test_all, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       0.25      0.26      0.25        99
#
#     accuracy                           1.00     56962
#    macro avg       0.62      0.63      0.63     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# ## Random forest (supervised)

# %%
param_grid = {'n_estimators': [100, 150, 200],
              'criterion': ['gini', 'entropy'],
             'min_samples_split': [2, 5]}

f1_ms = make_scorer(f1_score, average='binary', pos_label=1)

clf_rf = RandomForestClassifier(random_state=rseed)
clf_rf = GridSearchCV(clf_rf, param_grid, cv=cv, scoring=f1_ms, verbose=100)
clf_rf.fit(X_train_all, Y_train_all)
# Out:
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] criterion=gini, min_samples_split=2, n_estimators=100 ...........
# [CV]  criterion=gini, min_samples_split=2, n_estimators=100, score=1.000, total=  33.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   33.6s remaining:    0.0s
# [CV] criterion=gini, min_samples_split=2, n_estimators=150 ...........
# [CV]  criterion=gini, min_samples_split=2, n_estimators=150, score=1.000, total=  50.6s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.4min remaining:    0.0s
# [CV] criterion=gini, min_samples_split=2, n_estimators=200 ...........
# [CV]  criterion=gini, min_samples_split=2, n_estimators=200, score=1.000, total= 1.2min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.6min remaining:    0.0s
# [CV] criterion=gini, min_samples_split=5, n_estimators=100 ...........
# [CV]  criterion=gini, min_samples_split=5, n_estimators=100, score=1.000, total=  37.2s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  3.2min remaining:    0.0s
# [CV] criterion=gini, min_samples_split=5, n_estimators=150 ...........
# [CV]  criterion=gini, min_samples_split=5, n_estimators=150, score=1.000, total=  52.6s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.1min remaining:    0.0s
# [CV] criterion=gini, min_samples_split=5, n_estimators=200 ...........
# [CV]  criterion=gini, min_samples_split=5, n_estimators=200, score=1.000, total= 1.2min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  5.3min remaining:    0.0s
# [CV] criterion=entropy, min_samples_split=2, n_estimators=100 ........
# [CV]  criterion=entropy, min_samples_split=2, n_estimators=100, score=1.000, total=  36.2s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  5.9min remaining:    0.0s
# [CV] criterion=entropy, min_samples_split=2, n_estimators=150 ........
# [CV]  criterion=entropy, min_samples_split=2, n_estimators=150, score=1.000, total=  56.8s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  6.9min remaining:    0.0s
# [CV] criterion=entropy, min_samples_split=2, n_estimators=200 ........
# [CV]  criterion=entropy, min_samples_split=2, n_estimators=200, score=1.000, total= 1.3min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  8.2min remaining:    0.0s
# [CV] criterion=entropy, min_samples_split=5, n_estimators=100 ........
# [CV]  criterion=entropy, min_samples_split=5, n_estimators=100, score=1.000, total=  38.2s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  8.8min remaining:    0.0s
# [CV] criterion=entropy, min_samples_split=5, n_estimators=150 ........
# [CV]  criterion=entropy, min_samples_split=5, n_estimators=150, score=1.000, total=  57.6s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  9.8min remaining:    0.0s
# [CV] criterion=entropy, min_samples_split=5, n_estimators=200 ........
# [CV]  criterion=entropy, min_samples_split=5, n_estimators=200, score=1.000, total= 1.3min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 11.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 11.1min finished
# GridSearchCV(cv=ShuffleSplit(n_splits=1, random_state=1, test_size=0.2, train_size=None),
#              estimator=RandomForestClassifier(random_state=1),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 150, 200]},
#              scoring=make_scorer(f1_score, average=binary, pos_label=1),
#              verbose=100)

# %%
# Gridsearch Parameter Tuning result
print(clf_rf.best_params_)
print(clf_rf.best_score_)
dump(clf_rf.best_estimator_, open('random_forest.pkl', 'wb'))
# Out:
# {'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 100}
# 1.0

# %%
y_pred = clf_rf.best_estimator_.predict(X_test_all)
y_probs = clf_rf.best_estimator_.predict_proba(X_test_all)[:,1]

evaluation_matrix(Y_test_all, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       1.00      1.00      1.00        99
#
#     accuracy                           1.00     56962
#    macro avg       1.00      1.00      1.00     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# ## One-class SVM (semi-supervised)

# %%
param_grid = {'kernel': ['rbf'],
             'gamma': ['scale', 0.01, 0.1, 1],
             'nu': [0.1, 0.5, 1]}
f1_ms = make_scorer(f1_score)

clf_svm = OneClassSVM()
clf_svm = GridSearchCV(clf_svm, param_grid, cv=cv, scoring=f1_ms, verbose=100)

Y_train_normal_2 = Y_train_normal[:len(Y_train_normal)//10].copy()
Y_train_normal_2[Y_train_normal_2 == 1] = -1
Y_train_normal_2[Y_train_normal_2 == 0] = 1

clf_svm.fit(X_train_normal[:len(X_train_normal)//10], Y_train_normal_2)
# Out:
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] gamma=scale, kernel=rbf, nu=0.1 .................................
# [CV] ..... gamma=scale, kernel=rbf, nu=0.1, score=0.942, total=   2.9s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.8s remaining:    0.0s
# [CV] gamma=scale, kernel=rbf, nu=0.5 .................................
# [CV] ..... gamma=scale, kernel=rbf, nu=0.5, score=0.669, total=  13.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   15.8s remaining:    0.0s
# [CV] gamma=scale, kernel=rbf, nu=1 ...................................
# [CV] ....... gamma=scale, kernel=rbf, nu=1, score=0.000, total=  13.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   28.9s remaining:    0.0s
# [CV] gamma=0.01, kernel=rbf, nu=0.1 ..................................
# [CV] ...... gamma=0.01, kernel=rbf, nu=0.1, score=0.942, total=   2.8s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   31.7s remaining:    0.0s
# [CV] gamma=0.01, kernel=rbf, nu=0.5 ..................................
# [CV] ...... gamma=0.01, kernel=rbf, nu=0.5, score=0.669, total=  13.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   44.8s remaining:    0.0s
# [CV] gamma=0.01, kernel=rbf, nu=1 ....................................
# [CV] ........ gamma=0.01, kernel=rbf, nu=1, score=0.000, total=  12.9s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   57.7s remaining:    0.0s
# [CV] gamma=0.1, kernel=rbf, nu=0.1 ...................................
# [CV] ....... gamma=0.1, kernel=rbf, nu=0.1, score=0.942, total=   2.8s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.0min remaining:    0.0s
# [CV] gamma=0.1, kernel=rbf, nu=0.5 ...................................
# [CV] ....... gamma=0.1, kernel=rbf, nu=0.5, score=0.670, total=  13.1s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.2min remaining:    0.0s
# [CV] gamma=0.1, kernel=rbf, nu=1 .....................................
# [CV] ......... gamma=0.1, kernel=rbf, nu=1, score=0.000, total=  13.1s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.4min remaining:    0.0s
# [CV] gamma=1, kernel=rbf, nu=0.1 .....................................
# [CV] ......... gamma=1, kernel=rbf, nu=0.1, score=0.942, total=   2.9s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.5min remaining:    0.0s
# [CV] gamma=1, kernel=rbf, nu=0.5 .....................................
# [CV] ......... gamma=1, kernel=rbf, nu=0.5, score=0.669, total=  13.1s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  1.7min remaining:    0.0s
# [CV] gamma=1, kernel=rbf, nu=1 .......................................
# [CV] ........... gamma=1, kernel=rbf, nu=1, score=0.000, total=  13.1s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  1.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  1.9min finished
# GridSearchCV(cv=ShuffleSplit(n_splits=1, random_state=1, test_size=0.2, train_size=None),
#              estimator=OneClassSVM(),
#              param_grid={'gamma': ['scale', 0.01, 0.1, 1], 'kernel': ['rbf'],
#                          'nu': [0.1, 0.5, 1]},
#              scoring=make_scorer(f1_score), verbose=100)

# %%
# Gridsearch Parameter Tuning result
print(clf_svm.best_params_)
print(clf_svm.best_score_)
dump(clf_svm.best_estimator_, open('oneclass_svm.pkl', 'wb'))
# Out:
# {'gamma': 0.01, 'kernel': 'rbf', 'nu': 0.1}
# 0.9424619318842263

# %%
y_pred = clf_svm.best_estimator_.predict(X_test_all)
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1

evaluation_matrix(Y_test_all, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95     56863
#            1       0.02      1.00      0.03        99
#
#     accuracy                           0.90     56962
#    macro avg       0.51      0.95      0.49     56962
# weighted avg       1.00      0.90      0.94     56962

# %% [markdown]
# ## One-class Autoencoder
# 1. Hybrid (semi-supervised & supervised): encoder + classifier
# 1. Semi-supervised: using threshold

# %%
def create_model(optimizer='adam'):
    input_layer = Input(shape=(X_train_normal.shape[1],))

    ## encoding part
    encoded = Dense(128, activation='relu')(input_layer)
    encoded = Dense(64, activation='relu')(encoded)
    encoded = Dense(32, activation='relu')(encoded)

    ## decoding part
    decoded = Dense(32, activation='relu')(encoded)
    decoded = Dense(64, activation='relu')(decoded)
    decoded = Dense(128, activation='relu')(decoded)

    ## output layer
    output_layer = Dense(X_train_normal.shape[1], activation='relu')(decoded)

    autoencoder = Model(input_layer, output_layer)
    autoencoder.compile(optimizer=optimizer, loss="mse")
    
    return autoencoder

# %%
params = {'optimizer': ['SGD', 'Adam'],
          'epochs': [10, 50, 100]}

autoencoder = KerasRegressor(build_fn=create_model)

autoencoder_grid = GridSearchCV(autoencoder, param_grid=params, cv=cv, verbose=100, scoring='neg_mean_squared_error') 

autoencoder_grid.fit(X_train_normal, X_train_normal, shuffle=True)
# Out:
# Fitting 1 folds for each of 6 candidates, totalling 6 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] epochs=10, optimizer=SGD ........................................
# Epoch 1/10
# 5687/5687 [==============================] - 3s 514us/step - loss: 0.1100
# Epoch 2/10
# 5687/5687 [==============================] - 3s 516us/step - loss: 0.1034
# Epoch 3/10
# 5687/5687 [==============================] - 3s 521us/step - loss: 0.1034
# Epoch 4/10
# 5687/5687 [==============================] - 3s 529us/step - loss: 0.1034
# Epoch 5/10
# 5687/5687 [==============================] - 3s 546us/step - loss: 0.1034
# Epoch 6/10
# 5687/5687 [==============================] - 3s 552us/step - loss: 0.1034
# Epoch 7/10
# 5687/5687 [==============================] - 3s 523us/step - loss: 0.1034
# Epoch 8/10
# 5687/5687 [==============================] - 3s 541us/step - loss: 0.1034
# Epoch 9/10
# 5687/5687 [==============================] - 3s 520us/step - loss: 0.1034
# Epoch 10/10
# 5687/5687 [==============================] - 3s 515us/step - loss: 0.1034
# [CV] ........... epochs=10, optimizer=SGD, score=-0.103, total=  31.2s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   31.1s remaining:    0.0s
# [CV] epochs=10, optimizer=Adam .......................................
# Epoch 1/10
# 5687/5687 [==============================] - 4s 763us/step - loss: 0.1038
# Epoch 2/10
# 5687/5687 [==============================] - 4s 701us/step - loss: 0.0528
# Epoch 3/10
# 5687/5687 [==============================] - 4s 675us/step - loss: 0.0527
# Epoch 4/10
# 5687/5687 [==============================] - 4s 700us/step - loss: 0.0527
# Epoch 5/10
# 5687/5687 [==============================] - 4s 691us/step - loss: 0.0441
# Epoch 6/10
# 5687/5687 [==============================] - 4s 670us/step - loss: 0.0220
# Epoch 7/10
# 5687/5687 [==============================] - 4s 673us/step - loss: 0.0220
# Epoch 8/10
# 5687/5687 [==============================] - 4s 671us/step - loss: 0.0220
# Epoch 9/10
# 5687/5687 [==============================] - 4s 678us/step - loss: 0.0115
# Epoch 10/10
# 5687/5687 [==============================] - 4s 664us/step - loss: 0.0108
# [CV] .......... epochs=10, optimizer=Adam, score=-0.011, total=  40.2s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed
# 7108/7108 [==============================] - 5s 690us/step - loss: 1.4327e-05
# Epoch 91/100
# 7108/7108 [==============================] - 5s 719us/step - loss: 1.3461e-05
# Epoch 92/100
# 7108/7108 [==============================] - 5s 703us/step - loss: 1.3180e-05
# Epoch 93/100
# 7108/7108 [==============================] - 5s 679us/step - loss: 1.3072e-05
# Epoch 94/100
# 7108/7108 [==============================] - 5s 699us/step - loss: 1.2938e-05
# Epoch 95/100
# 7108/7108 [==============================] - 5s 700us/step - loss: 1.2664e-05
# Epoch 96/100
# 7108/7108 [==============================] - 5s 708us/step - loss: 1.2349e-05
# Epoch 97/100
# 7108/7108 [==============================] - 5s 695us/step - loss: 1.2650e-05
# Epoch 98/100
# 7108/7108 [==============================] - 5s 682us/step - loss: 1.2081e-05
# Epoch 99/100
# 7108/7108 [==============================] - 5s 676us/step - loss: 1.2382e-05
# Epoch 100/100
# 7108/7108 [==============================] - 5s 672us/step - loss: 1.2005e-05
# GridSearchCV(cv=ShuffleSplit(n_splits=1, random_state=1, test_size=0.2, train_size=None),
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasRegressor object at 0x000001C08769FBE0>,
#              param_grid={'epochs': [10, 50, 100], 'optimizer': ['SGD', 'Adam']},
#              scoring='neg_mean_squared_error', verbose=100)

# %%
# Gridsearch Parameter Tuning result
print(autoencoder_grid.best_params_)
print(autoencoder_grid.best_score_)
autoencoder_grid.best_estimator_.model.save('oneclass_ae.hd5')
# Out:
# {'epochs': 100, 'optimizer': 'Adam'}
# -3.619648759265042e-05
# WARNING:tensorflow:From C:\Users\SAMSUNG\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\SAMSUNG\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: oneclass_ae.hd5\assets

# %% [markdown]
# ### Hybrid (semi-supervised & supervised): encoder + classifier

# %%
# Encoder
encoder = Sequential()
encoder.add(autoencoder_grid.best_estimator_.model.layers[0])
encoder.add(autoencoder_grid.best_estimator_.model.layers[1])
encoder.add(autoencoder_grid.best_estimator_.model.layers[2])

train_all_rep = encoder.predict(X_train_all)
test_all_rep = encoder.predict(X_test_all)

# %%
# classifier
clf = LogisticRegression().fit(train_all_rep, Y_train_all)
y_pred = clf.predict(test_all_rep)
evaluation_matrix(Y_test_all, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       0.90      0.70      0.78        99
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.85      0.89     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# ### Semi-supervised: error threshold-based

# %%
pred = autoencoder_grid.best_estimator_.model.predict(X_test_all)
mse = np.mean(np.power(X_test_all - pred, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse, 'true_class': Y_test_all})
true_error = error_df[error_df['true_class']==0]
recons_error = true_error['reconstruction_error'].values

# %%
error_df.iloc[56500:,0].plot()

# %%
threshold = max(recons_error)
threshold
# Out:
# 0.006786039896446198

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
evaluation_matrix(error_df.true_class, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       1.00      1.00      1.00        99
#
#     accuracy                           1.00     56962
#    macro avg       1.00      1.00      1.00     56962
# weighted avg       1.00      1.00      1.00     56962
